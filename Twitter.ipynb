# %% [markdown]
# # Example 1. Authorizing an application to access Twitter account data

# %%
import twitter
# Go to http://dev.twitter.com/apps/new to create an app and get values
# for these credentials, which you'll need to provide in place of these
# empty string values that are defined as placeholders.
# See https://dev.twitter.com/docs/auth/oauth for more information 
# on Twitter's OAuth implementation.

CONSUMER_KEY = 'ogPne6LCzy0TgeCbtpTyMoFzh'
CONSUMER_SECRET ='IN25rxolldcxX5gz3xsSgGbZwBcsYuPuFLnoNzyFRNtIBvmuBi'
#OAUTH_TOKEN = '571213367-jAEYPDKJy2T6PjrqmmAsxF6Bq1uJ8s0ADed1kqae'
OAUTH_TOKEN = '571213367-jAEYPDKJy2T6PjrqmmAsxF6Bq1uJ8s0ADed1kqae'
OAUTH_TOKEN_SECRET = 'BCB5LnJ5eImhc4jSFER0H0uZC7eEmqToiC3zSRxyc1t67'

auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                           CONSUMER_KEY, CONSUMER_SECRET)

twitter_api = twitter.Twitter(auth=auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print(twitter_api)
# Out:
# <twitter.api.Twitter object at 0x00000243ACD28160>

# %% [markdown]
# ## Back to slides

# %% [markdown]
# # Example 2. Retrieving trends

# %%
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/

WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)

print(world_trends)
# Out:
# [{'as_of': '2017-09-09T18:06:31Z', 'trends': [{'url': 'http://twitter.com/search?q=%23STKMUN', 'promoted_content': None, 'name': '#STKMUN', 'query': '%23STKMUN', 'tweet_volume': 41185}, {'url': 'http://twitter.com/search?q=%23JuveChievo', 'promoted_content': None, 'name': '#JuveChievo', 'query': '%23JuveChievo', 'tweet_volume': 22833}, {'url': 'http://twitter.com/search?q=%E3%81%82%E3%81%AA%E3%81%9F%E3%81%AEpixiv%E5%8F%B2', 'promoted_content': None, 'name': 'あなたのpixiv史', 'query': '%E3%81%82%E3%81%AA%E3%81%9F%E3%81%AEpixiv%E5%8F%B2', 'tweet_volume': 19214}, {'url': 'http://twitter.com/search?q=%22Lamar+Jackson%22', 'promoted_content': None, 'name': 'Lamar Jackson', 'query': '%22Lamar+Jackson%22', 'tweet_volume': 11347}, {'url': 'http://twitter.com/search?q=%23%D8%B9%D9%88%D8%AF%D9%87_%D8%A7%D9%84%D9%85%D8%B9%D9%84%D9%85%D9%8A%D9%86_%D9%88%D8%A7%D9%84%D9%85%D8%B9%D9%84%D9%85%D8%A7%D8%AA', 'promoted_content': None, 'name': '#عوده_المعلمين_والمعلمات', 'query': '%23%D8%B9%D9%88%D8%AF%D9%87_%D8%A7%D9%84%D9%85%D8%B9%D9%84%D9%85%D9%8A%D9%86_%D9%88%D8%A7%D9%84%D9%85%D8%B9%D9%84%D9%85%D8%A7%D8%AA', 'tweet_volume': 13082}, {'url': 'http://twitter.com/search?q=%23TSGFCB', 'promoted_content': None, 'name': '#TSGFCB', 'query': '%23TSGFCB', 'tweet_volume': None}, {'url': 'http://twitter.com/search?q=%23Welcome5SOStoArgentina', 'promoted_content': None, 'name': '#Welcome5SOStoArgentina', 'query': '%23Welcome5SOStoArgentina', 'tweet_volume': 48155}, {'url': 'http://twitter.com/search?q=Contador', 'promoted_content': None, 'name': 'Contador', 'query': 'Contador', 'tweet_volume': 53628}, {'url': 'http://twitter.com/search?q=Liverpool', 'promoted_content': None, 'name': 'Liverpool', 'query': 'Liverpool', 'tweet_volume': 379522}, {'url': 'http://twitter.com/search?q=%22Phil+Jones%22', 'promoted_content': None, 'name': 'Phil Jones', 'query': '%22Phil+Jones%22', 'tweet_volume': None}, {'url': 'http://twitter.com/search?q=Bayern', 'promoted_content': None, 'name': 'Bayern', 'query': 'Bayern', 'tweet_volume': 20590}, {'url': 'http://twitter.com/search?q=Darmian', 'promoted_content': None, 'name': 'Darmian', 'query': 'Darmian', 'tweet_volume': None}, {'url': 'http://twitter.com/search?q=Hoffenheim', 'promoted_content': None, 'name': 'Hoffenheim', 'query': 'Hoffenheim', 'tweet_volume': None}, {'url': 'http://twitter.com/search?q=Morata', 'promoted_content': None, 'name': 'Morata', 'query': 'Morata', 'tweet_volume': 78511}, {'url': 'http://twitter.com/search?q=%22Harry+Kane%22', 'promoted_content': None, 'name': 'Harry Kane', 'query': '%22Harry+Kane%22', 'tweet_volume': 24339}, {'url': 'http://twitter.com/search?q=Mkhitaryan', 'promoted_content': None, 'name': 'Mkhitaryan', 'query': 'Mkhitaryan', 'tweet_volume': None}, {'url': 'http://twitter.com/search?q=Sendic', 'promoted_content': None, 'name': 'Sendic', 'query': 'Sendic', 'tweet_volume': 14375}, {'url': 'http://twitter.com/search?q=%22Volkan+Demirel%22', 'promoted_content': None, 'name': 'Volkan Demirel', 'query': '%22Volkan+Demirel%22', 'tweet_volume': None}, {'url': 'http://twitter.com/search?q=Bailly', 'promoted_content': None, 'name': 'Bailly', 'query': 'Bailly', 'tweet_volume': None}, {'url': 'http://twitter.com/search?q=%22Decorated+Knight%22', 'promoted_content': None, 'name': 'Decorated Knight', 'query': '%22Decorated+Knight%22', 'tweet_volume': None}, {'url': 'http://twitter.com/search?q=Ganso', 'promoted_content': None, 'name': 'Ganso', 'query': 'Ganso', 'tweet_volume': None}, {'url': 'http://twitter.com/search?q=%22Carter+3%22', 'promoted_content': None, 'name': 'Carter 3', 'query': '%22Carter+3%22', 'tweet_volume': 12964}, {'url': 'http://twitter.com/search?q=Welbeck', 'promoted_content': None, 'name': 'Welbeck', 'query': 'Welbeck', 'tweet_volume': 31578}, {'url': 'http://twitter.com/search?q=%23OGCNASM', 'promoted_content': None, 'name': '#OGCNASM', 'query': '%23OGCNASM', 'tweet_volume': 18366}, {'url': 'http://twitter.com/search?q=%23BTS_CB_PARTY', 'promoted_content': None, 'name': '#BT ...

# %%
print(us_trends)
# Out:
# [{'as_of': '2017-09-09T18:06:31Z', 'trends': [{'url': 'http://twitter.com/search?q=%22Lamar+Jackson%22', 'promoted_content': None, 'name': 'Lamar Jackson', 'query': '%22Lamar+Jackson%22', 'tweet_volume': None}, {'url': 'http://twitter.com/search?q=%23saturdaymorning', 'promoted_content': None, 'name': '#saturdaymorning', 'query': '%23saturdaymorning', 'tweet_volume': 31476}, {'url': 'http://twitter.com/search?q=%23CollegeGameDay', 'promoted_content': None, 'name': '#CollegeGameDay', 'query': '%23CollegeGameDay', 'tweet_volume': None}, {'url': 'http://twitter.com/search?q=%22Carter+3%22', 'promoted_content': None, 'name': 'Carter 3', 'query': '%22Carter+3%22', 'tweet_volume': 12624}, {'url': 'http://twitter.com/search?q=%22Jonathan+Taylor%22', 'promoted_content': None, 'name': 'Jonathan Taylor', 'query': '%22Jonathan+Taylor%22', 'tweet_volume': None}, {'url': 'http://twitter.com/search?q=%22Iowa+State%22', 'promoted_content': None, 'name': 'Iowa State', 'query': '%22Iowa+State%22', 'tweet_volume': None}, {'url': 'http://twitter.com/search?q=%23STKMUN', 'promoted_content': None, 'name': '#STKMUN', 'query': '%23STKMUN', 'tweet_volume': 39990}, {'url': 'http://twitter.com/search?q=%22Brandon+Harris%22', 'promoted_content': None, 'name': 'Brandon Harris', 'query': '%22Brandon+Harris%22', 'tweet_volume': None}, {'url': 'http://twitter.com/search?q=%22Stephen+Johnson%22', 'promoted_content': None, 'name': 'Stephen Johnson', 'query': '%22Stephen+Johnson%22', 'tweet_volume': None}, {'url': 'http://twitter.com/search?q=Speight', 'promoted_content': None, 'name': 'Speight', 'query': 'Speight', 'tweet_volume': None}, {'url': 'http://twitter.com/search?q=%23WRBGFest', 'promoted_content': None, 'name': '#WRBGFest', 'query': '%23WRBGFest', 'tweet_volume': None}, {'url': 'http://twitter.com/search?q=%23CINvsMICH', 'promoted_content': None, 'name': '#CINvsMICH', 'query': '%23CINvsMICH', 'tweet_volume': None}, {'url': 'http://twitter.com/search?q=%22Category+3%22', 'promoted_content': None, 'name': 'Category 3', 'query': '%22Category+3%22', 'tweet_volume': 11369}, {'url': 'http://twitter.com/search?q=%22Lynn+Bowden%22', 'promoted_content': None, 'name': 'Lynn Bowden', 'query': '%22Lynn+Bowden%22', 'tweet_volume': None}, {'url': 'http://twitter.com/search?q=%22UT+Martin%22', 'promoted_content': None, 'name': 'UT Martin', 'query': '%22UT+Martin%22', 'tweet_volume': None}, {'url': 'http://twitter.com/search?q=%22Will+Grier%22', 'promoted_content': None, 'name': 'Will Grier', 'query': '%22Will+Grier%22', 'tweet_volume': None}, {'url': 'http://twitter.com/search?q=%22Devin+Bush%22', 'promoted_content': None, 'name': 'Devin Bush', 'query': '%22Devin+Bush%22', 'tweet_volume': None}, {'url': 'http://twitter.com/search?q=%22Drew+Barker%22', 'promoted_content': None, 'name': 'Drew Barker', 'query': '%22Drew+Barker%22', 'tweet_volume': None}, {'url': 'http://twitter.com/search?q=%22Eastern+Kentucky%22', 'promoted_content': None, 'name': 'Eastern Kentucky', 'query': '%22Eastern+Kentucky%22', 'tweet_volume': None}, {'url': 'http://twitter.com/search?q=%22Chazz+Surratt%22', 'promoted_content': None, 'name': 'Chazz Surratt', 'query': '%22Chazz+Surratt%22', 'tweet_volume': None}, {'url': 'http://twitter.com/search?q=%22Daniel+Jones%22', 'promoted_content': None, 'name': 'Daniel Jones', 'query': '%22Daniel+Jones%22', 'tweet_volume': None}, {'url': 'http://twitter.com/search?q=Stoke', 'promoted_content': None, 'name': 'Stoke', 'query': 'Stoke', 'tweet_volume': 74886}, {'url': 'http://twitter.com/search?q=%22Mike+Boone%22', 'promoted_content': None, 'name': 'Mike Boone', 'query': '%22Mike+Boone%22', 'tweet_volume': None}, {'url': 'http://twitter.com/search?q=%22Tyree+Kinnel%22', 'promoted_content': None, 'name': 'Tyree Kinnel', 'query': '%22Tyree+Kinnel%22', 'tweet_volume': None}, {'url': 'http://twitter.com/search?q=Stanley', 'promoted_content': None, 'name': 'Stanley', 'query': 'Stanley', 'tweet_volume': 10973}, {'url': 'http://twitter.com/search?q=%22Kyzir+Whi ...

# %%
import json
data= json.dumps(us_trends, indent=1)

file = open('foo.txt','w')
file.write(data)
file.close()

# %%
file = open('foo.txt','r')
foo = file.read()
d = json.loads(foo)

print(len(d))
print(d[0].keys())
print(len(d[0]['trends']))
print(d[0]['trends'][27])
# Out:
# 1
# dict_keys(['as_of', 'trends', 'created_at', 'locations'])
# 50
# {'url': 'http://twitter.com/search?q=%22Kendall+Adams%22', 'promoted_content': None, 'name': 'Kendall Adams', 'query': '%22Kendall+Adams%22', 'tweet_volume': None}

# %% [markdown]
# ## Back to slides

# %% [markdown]
# # Example 3. Displaying API responses as pretty-printed JSON

# %%
import json

#print(json.dumps(world_trends, indent=1))
print(json.dumps(us_trends, indent=1))
# Out:
# [
#  {
#   "as_of": "2017-09-09T18:06:31Z",
#   "trends": [
#    {
#     "url": "http://twitter.com/search?q=%22Lamar+Jackson%22",
#     "promoted_content": null,
#     "name": "Lamar Jackson",
#     "query": "%22Lamar+Jackson%22",
#     "tweet_volume": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23saturdaymorning",
#     "promoted_content": null,
#     "name": "#saturdaymorning",
#     "query": "%23saturdaymorning",
#     "tweet_volume": 31476
#    },
#    {
#     "url": "http://twitter.com/search?q=%23CollegeGameDay",
#     "promoted_content": null,
#     "name": "#CollegeGameDay",
#     "query": "%23CollegeGameDay",
#     "tweet_volume": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Carter+3%22",
#     "promoted_content": null,
#     "name": "Carter 3",
#     "query": "%22Carter+3%22",
#     "tweet_volume": 12624
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Jonathan+Taylor%22",
#     "promoted_content": null,
#     "name": "Jonathan Taylor",
#     "query": "%22Jonathan+Taylor%22",
#     "tweet_volume": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Iowa+State%22",
#     "promoted_content": null,
#     "name": "Iowa State",
#     "query": "%22Iowa+State%22",
#     "tweet_volume": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23STKMUN",
#     "promoted_content": null,
#     "name": "#STKMUN",
#     "query": "%23STKMUN",
#     "tweet_volume": 39990
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Brandon+Harris%22",
#     "promoted_content": null,
#     "name": "Brandon Harris",
#     "query": "%22Brandon+Harris%22",
#     "tweet_volume": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Stephen+Johnson%22",
#     "promoted_content": null,
#     "name": "Stephen Johnson",
#     "query": "%22Stephen+Johnson%22",
#     "tweet_volume": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Speight",
#     "promoted_content": null,
#     "name": "Speight",
#     "query": "Speight",
#     "tweet_volume": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23WRBGFest",
#     "promoted_content": null,
#     "name": "#WRBGFest",
#     "query": "%23WRBGFest",
#     "tweet_volume": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23CINvsMICH",
#     "promoted_content": null,
#     "name": "#CINvsMICH",
#     "query": "%23CINvsMICH",
#     "tweet_volume": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Category+3%22",
#     "promoted_content": null,
#     "name": "Category 3",
#     "query": "%22Category+3%22",
#     "tweet_volume": 11369
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Lynn+Bowden%22",
#     "promoted_content": null,
#     "name": "Lynn Bowden",
#     "query": "%22Lynn+Bowden%22",
#     "tweet_volume": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22UT+Martin%22",
#     "promoted_content": null,
#     "name": "UT Martin",
#     "query": "%22UT+Martin%22",
#     "tweet_volume": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Will+Grier%22",
#     "promoted_content": null,
#     "name": "Will Grier",
#     "query": "%22Will+Grier%22",
#     "tweet_volume": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Devin+Bush%22",
#     "promoted_content": null,
#     "name": "Devin Bush",
#     "query": "%22Devin+Bush%22",
#     "tweet_volume": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Drew+Barker%22",
#     "promoted_content": null,
#     "name": "Drew Barker",
#     "query": "%22Drew+Barker%22",
#     "tweet_volume": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Eastern+Kentucky%22",
#     "promoted_content": null,
#     "name": "Eastern Kentucky",
#     "query": "%22Eastern+Kentucky%22",
#     "tweet_volume": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Chazz+Surratt%22",
#     "promoted_content": null,
#     "name": "Chazz Surratt",
#     "query": "%22Chazz+Surratt%22",
#     "tweet_volume": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Daniel+Jones%22",
#     "promoted_content": null,
#     "name": "Daniel Jones",
#     "query": "%22Daniel+Jones%22",
#     "tweet_volume": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Stoke",
#     "promoted_content": null,
#     "name": "Stoke",
#     "query": "Stoke",
#     "tweet_volume": 74886
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Mike+Boone%22",
#     "promoted_content": null,
#     "name": "Mike Boone",
#     "query": "%22Mike+Boone%22",
#     "tweet_volume": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Tyree+Kinnel%22",
#     "promoted_content": null,
#     "name": "Tyree Kinnel",
#     "query": "%22Tyree+Kinnel%22",
#     "tweet_volume": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Stanley",
#     "promoted_content": null,
#     "name": "Stanley",
#     "query": "Stanley",
#     "tweet_volume": 10973
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Kyzir+White%22",
#     "promoted_content": null,
#     "name": "Kyzir White",
#     "query": "%22Kyzir+White%22",
#     "tweet_volume": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Kasim+Hill%22",
#     "promoted_content": null,
#     "name": "Kasim Hill",
#     "query": "%22Kasim+Hill%22",
#     "tweet_volume": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Kendall+Adams%22",
#     "promoted_content": null,
#     "name": "Kendall Adams",
#     "query": "%22Kendall+Adams%22",
#     "tweet_volume": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Rashford",
#     "promoted_content": null,
#     "name": "Rashford",
#     "query": "Rashford",
#     "tweet_volume": 21420
#    },
#    {
#     "url": "http://twitter.com/search?q=Wadley",
#     "promoted_content": null,
#     "name": "Wadley",
#     "query": "Wadley",
#     "tweet_volume": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Liverpool",
#     "promoted_content": null,
#     "name": "Liverpool",
#     "query": "Liverpool",
#     "tweet_volume": 382400
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Joe+Paterno%22",
#     "promoted_content": null,
#     "name": "Joe Paterno",
#     "query": "%22Joe+Paterno%22",
#     "tweet_volume": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Shea+Patterson%22",
#     "promoted_content": null,
#     "name": "Shea Patterson",
#     "query": "%22Shea+Patterson%22",
#     "tweet_volume": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22David+Montgomery%22",
#     "promoted_content": null,
#     "name": "David Montgomery",
#     "query": "%22David+Montgomery%22",
#     "tweet_volume": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Terry+Gross%22",
#     "promoted_content": null,
#     "name": "Terry Gross",
#     "query": "%22Terry+Gross%22",
#     "tweet_volume": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Tar+Heels%22",
#     "promoted_content": null,
#     "name": "Tar Heels",
#     "query": "%22Tar+Heels%22",
#     "tweet_volume": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Austin+MacGinnis%22",
#     "promoted_content": null,
#     "name": "Austin MacGinnis",
#     "query": "%22Austin+MacGinnis%22",
#     "tweet_volume": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Lacazette",
#     "promoted_content": null,
#     "name": "Lacazette",
#     "query": "Lacazette",
#     "tweet_volume": 31928
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Kroger+Field%22",
#     "promoted_content": null,
#     "name": "Kroger Field",
#     "query": "%22Kroger+Field%22",
#     "tweet_volume": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22De+Gea%22",
#     "promoted_content": null,
#     "name": "De Gea",
#     "query": "%22De+Gea%22",
#     "tweet_volume": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Lukaku",
#     "promoted_content": null,
#     "name": "Lukaku",
#     "query": "Lukaku",
#     "tweet_volume": 30179
#    },
#    {
#     "url": "http://twitter.com/search?q=%23AdamSandlerAMovie",
#     "promoted_content": null,
#     "name": "#AdamSandlerAMovie",
#     "query": "%23AdamSandlerAMovie",
#     "tweet_volume": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23TheseLyricsDescribeMe",
#     "promoted_content": null,
#     "name": "#TheseLyricsDescribeMe",
#     "query": "%23TheseLyricsDescribeMe",
#     "tweet_volume": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23CreateCultivateSEA",
#     "promoted_content": null,
#     "name": "#CreateCultivateSEA",
#     "query": "%23CreateCultivateSEA",
#     "tweet_volume": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23COYS",
#     "promoted_content": null,
#     "name": "#COYS",
#     "query": "%23COYS",
#     "tweet_volume": 23965
#    },
#    {
#     "url": "http://twitter.com/search?q=%23DragCon",
#     "promoted_content": null,
#     "name": "#DragCon",
#     "query": "%23DragCon",
#     "tweet_volume": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23CyHawk",
#     "promoted_content": null,
#     "name": "#CyHawk",
#     "query": "%23CyHawk",
#     "tweet_volume": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23TSGFCB",
#     "promoted_content": null,
#     "name": "#TSGFCB",
#     "query": "%23TSGFCB",
#     "tweet_volume": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23LDP2017",
#     "promoted_content": null,
#     "name": "#LDP2017",
#     "query": "%23LDP2017",
#     "tweet_volume": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23ULvsUNC",
#     "promoted_content": null,
#     "name": "#ULvsUNC",
#     "query": "%23ULvsUNC",
#     "tweet_volume": null
#    }
#   ],
#   "created_at": "2017-09-09T17:58:05Z",
#   "locations": [
#    {
#     "woeid": 23424977,
#     "name": "United States"
#    }
#   ]
#  }
# ]

# %%
len(us_trends[0]['trends'])
for i in range(50):
    print(us_trends[0]['trends'][i]['url'])
    print(us_trends[0]['trends'][i]['query'])
# Out:
# http://twitter.com/search?q=%22Lamar+Jackson%22
# %22Lamar+Jackson%22
# http://twitter.com/search?q=%23saturdaymorning
# %23saturdaymorning
# http://twitter.com/search?q=%23CollegeGameDay
# %23CollegeGameDay
# http://twitter.com/search?q=%22Carter+3%22
# %22Carter+3%22
# http://twitter.com/search?q=%22Jonathan+Taylor%22
# %22Jonathan+Taylor%22
# http://twitter.com/search?q=%22Iowa+State%22
# %22Iowa+State%22
# http://twitter.com/search?q=%23STKMUN
# %23STKMUN
# http://twitter.com/search?q=%22Brandon+Harris%22
# %22Brandon+Harris%22
# http://twitter.com/search?q=%22Stephen+Johnson%22
# %22Stephen+Johnson%22
# http://twitter.com/search?q=Speight
# Speight
# http://twitter.com/search?q=%23WRBGFest
# %23WRBGFest
# http://twitter.com/search?q=%23CINvsMICH
# %23CINvsMICH
# http://twitter.com/search?q=%22Category+3%22
# %22Category+3%22
# http://twitter.com/search?q=%22Lynn+Bowden%22
# %22Lynn+Bowden%22
# http://twitter.com/search?q=%22UT+Martin%22
# %22UT+Martin%22
# http://twitter.com/search?q=%22Will+Grier%22
# %22Will+Grier%22
# http://twitter.com/search?q=%22Devin+Bush%22
# %22Devin+Bush%22
# http://twitter.com/search?q=%22Drew+Barker%22
# %22Drew+Barker%22
# http://twitter.com/search?q=%22Eastern+Kentucky%22
# %22Eastern+Kentucky%22
# http://twitter.com/search?q=%22Chazz+Surratt%22
# %22Chazz+Surratt%22
# http://twitter.com/search?q=%22Daniel+Jones%22
# %22Daniel+Jones%22
# http://twitter.com/search?q=Stoke
# Stoke
# http://twitter.com/search?q=%22Mike+Boone%22
# %22Mike+Boone%22
# http://twitter.com/search?q=%22Tyree+Kinnel%22
# %22Tyree+Kinnel%22
# http://twitter.com/search?q=Stanley
# Stanley
# http://twitter.com/search?q=%22Kyzir+White%22
# %22Kyzir+White%22
# http://twitter.com/search?q=%22Kasim+Hill%22
# %22Kasim+Hill%22
# http://twitter.com/search?q=%22Kendall+Adams%22
# %22Kendall+Adams%22
# http://twitter.com/search?q=Rashford
# Rashford
# http://twitter.com/search?q=Wadley
# Wadley
# http://twitter.com/search?q=Liverpool
# Liverpool
# http://twitter.com/search?q=%22Joe+Paterno%22
# %22Joe+Paterno%22
# http://twitter.com/search?q=%22Shea+Patterson%22
# %22Shea+Patterson%22
# http://twitter.com/search?q=%22David+Montgomery%22
# %22David+Montgomery%22
# http://twitter.com/search?q=%22Terry+Gross%22
# %22Terry+Gross%22
# http://twitter.com/search?q=%22Tar+Heels%22
# %22Tar+Heels%22
# http://twitter.com/search?q=%22Austin+MacGinnis%22
# %22Austin+MacGinnis%22
# http://twitter.com/search?q=Lacazette
# Lacazette
# http://twitter.com/search?q=%22Kroger+Field%22
# %22Kroger+Field%22
# http://twitter.com/search?q=%22De+Gea%22
# %22De+Gea%22
# http://twitter.com/search?q=Lukaku
# Lukaku
# http://twitter.com/search?q=%23AdamSandlerAMovie
# %23AdamSandlerAMovie
# http://twitter.com/search?q=%23TheseLyricsDescribeMe
# %23TheseLyricsDescribeMe
# http://twitter.com/search?q=%23CreateCultivateSEA
# %23CreateCultivateSEA
# http://twitter.com/search?q=%23COYS
# %23COYS
# http://twitter.com/search?q=%23DragCon
# %23DragCon
# http://twitter.com/search?q=%23CyHawk
# %23CyHawk
# http://twitter.com/search?q=%23TSGFCB
# %23TSGFCB
# http://twitter.com/search?q=%23LDP2017
# %23LDP2017
# http://twitter.com/search?q=%23ULvsUNC
# %23ULvsUNC

# %% [markdown]
# # Example 4. Computing the intersection of two sets of trends

# %%
world_trends_set = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

us_trends_set = set([trend['name'] 
                     for trend in us_trends[0]['trends']]) 

common_trends = world_trends_set.intersection(us_trends_set)

print(common_trends)
# Out:
# {'Carter 3', '#saturdaymorning', '#TSGFCB', 'Liverpool', '#STKMUN', 'Lamar Jackson', '#CollegeGameDay'}

# %%
world_trends[0]['trends'][0]['name']
# Out:
# '#STKMUN'

# %%
world_trends_set
# Out:
# {'#9Sep',
#  '#BTS_CB_PARTY',
#  '#BarcaSiBartoNo',
#  '#CollegeGameDay',
#  '#DaveSaves',
#  '#DiaMundialDeLaArepa',
#  '#ElPapaEnMedellin',
#  '#FelizSabado',
#  '#ItaliaFinlandia',
#  '#JuveChievo',
#  '#LaikEğitimÇünkü',
#  '#MMKHopeForMarawi',
#  '#OGCNASM',
#  '#STKMUN',
#  '#SpyderAudioLaunch',
#  '#SuggestNamesForABrexiteerPub',
#  '#TSGFCB',
#  '#ValenciaAtleti',
#  '#WeAreManchester',
#  '#Welcome5SOStoArgentina',
#  '#herfey',
#  '#lufc',
#  '#saturdaymorning',
#  '#scfbvb',
#  '#الشباب_الباطن',
#  '#الفيحاء_التعاون',
#  '#توقع_مع_موج_الهلال',
#  '#طريق_الموت_العقير',
#  '#عوده_المعلمين_والمعلمات',
#  '#مانشستر_سيتي_ليفربول',
#  '#هنختار_السيسي_تاني',
#  '#비투비_2000일_예지앞사',
#  'Bailly',
#  'Bayern',
#  'Carter 3',
#  'Contador',
#  'Darmian',
#  'Decorated Knight',
#  'Ganso',
#  'Harry Kane',
#  'Hoffenheim',
#  'Lamar Jackson',
#  'Liverpool',
#  'Mkhitaryan',
#  'Morata',
#  'Phil Jones',
#  'Sendic',
#  'Volkan Demirel',
#  'Welbeck',
#  'あなたのpixiv史'}

# %%
print(u'#\u0645\u0639\u0644\u0645\u064a\u0646_\u0627\u0644\u0627\u0631\u0628\u0639_\u0639\u0627\u0644\u0631\u0627\u062f\u064a\u0648_9090')
# Out:
# #معلمين_الاربع_عالراديو_9090

# %%
print(u'#\u0628\u0642\u0648\u0644_\u0643\u0641\u0627\u064a\u0647_\u0644')
# Out:
# #بقول_كفايه_ل

# %% [markdown]
# # Example 5. Collecting search results

# %%
#  Set this variable to a trending topic, 
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter.
import json

#q = '#Kayne' 
q = '#Paffenroth' 
q = '#Toyota'

count = 1000

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = twitter_api.search.tweets(q=q, count=count)

statuses = search_results['statuses']


# Iterate through 5 more batches of results by following the cursor

for _ in range(5):
    print("Length of statuses", len(statuses))
    try:
        next_results = search_results['search_metadata']['next_results']
    except KeyError: # No more results when next_results doesn't exist
        break
        
    # Create a dictionary from next_results, which has the following form:
    # ?max_id=313519052523986943&q=NCAA&include_entities=1
    kwargs = dict([ kv.split('=') for kv in next_results[1:].split("&") ])
    
    search_results = twitter_api.search.tweets(**kwargs)
    statuses += search_results['statuses']

# Show one sample search result by slicing the list...
print(json.dumps(statuses, indent=4))
# Out:
# Length of statuses 100
# Length of statuses 200
# Length of statuses 200
# [
#     {
#         "created_at": "Fri Sep 08 00:22:17 +0000 2017",
#         "id": 905949374949187584,
#         "id_str": "905949374949187584",
#         "text": "RT @gooauto: \u76f4\u611f\u3067\u3044\u3044\u306a\u3041\u3063\u3066\u601d\u3063\u305f\u4eba\u306fRT\ud83d\ude0f\n\n#toyota #supra #jdm https://t.co/ZnNjqbLITT",
#         "truncated": false,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "toyota",
#                     "indices": [
#                         32,
#                         39
#                     ]
#                 },
#                 {
#                     "text": "supra",
#                     "indices": [
#                         40,
#                         46
#                     ]
#                 },
#                 {
#                     "text": "jdm",
#                     "indices": [
#                         47,
#                         51
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [
#                 {
#                     "screen_name": "gooauto",
#                     "name": "\u6c17\u306b\u306a\u308b\u8eca\u30fb\u30d0\u30a4\u30af\u52d5\u753b\u2744\ufe0f",
#                     "id": 3075512468,
#                     "id_str": "3075512468",
#                     "indices": [
#                         3,
#                         11
#                     ]
#                 }
#             ],
#             "urls": [],
#             "media": [
#                 {
#                     "id": 905928841771831300,
#                     "id_str": "905928841771831300",
#                     "indices": [
#                         52,
#                         75
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/DJKBe1WXUAQoYV3.jpg",
#                     "media_url_https": "https://pbs.twimg.com/media/DJKBe1WXUAQoYV3.jpg",
#                     "url": "https://t.co/ZnNjqbLITT",
#                     "display_url": "pic.twitter.com/ZnNjqbLITT",
#                     "expanded_url": "https://twitter.com/gooauto/status/905928843566952449/photo/1",
#                     "type": "photo",
#                     "sizes": {
#                         "large": {
#                             "w": 640,
#                             "h": 467,
#                             "resize": "fit"
#                         },
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "small": {
#                             "w": 640,
#                             "h": 467,
#                             "resize": "fit"
#                         },
#                         "medium": {
#                             "w": 640,
#                             "h": 467,
#                             "resize": "fit"
#                         }
#                     },
#                     "source_status_id": 905928843566952449,
#                     "source_status_id_str": "905928843566952449",
#                     "source_user_id": 3075512468,
#                     "source_user_id_str": "3075512468"
#                 }
#             ]
#         },
#         "extended_entities": {
#             "media": [
#                 {
#                     "id": 905928841771831300,
#                     "id_str": "905928841771831300",
#                     "indices": [
#                         52,
#                         75
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/DJKBe1WXUAQoYV3.jpg",
#                     "media_url_https": "https://pbs.twimg.com/media/DJKBe1WXUAQoYV3.jpg",
#                     "url": "https://t.co/ZnNjqbLITT",
#                     "display_url": "pic.twitter.com/ZnNjqbLITT",
#                     "expanded_url": "https://twitter.com/gooauto/status/905928843566952449/photo/1",
#                     "type": "photo",
#                     "sizes": {
#                         "large": {
#                             "w": 640,
#                             "h": 467,
#                             "resize": "fit"
#                         },
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "small": {
#                             "w": 640,
#                             "h": 467,
#                             "resize": "fit"
#                         },
#                         "medium": {
#                             "w": 640,
#                             "h": 467,
#                             "resize": "fit"
#                         }
#                     },
#                     "source_status_id": 905928843566952449,
#                     "source_status_id_str": "905928843566952449",
#                     "source_user_id": 3075512468,
#                     "source_user_id_str": "3075512468"
#                 }
#             ]
#         },
#         "metadata": {
#             "iso_language_code": "ja",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 384511849,
#             "id_str": "384511849",
#             "name": "\u3084\u3093\u72ac=\u8d85\u3069\u5e95\u8fba\u6b4c\u3044\u624b\u7684\u306a\u751f\u7269\u3002",
#             "screen_name": "6yanken9",
#             "location": "\u611b\u5a9b",
#             "description": "\u306f\u3058\u3081\u307e\u3057\u3066\u30cb\u30b3\u30cb\u30b3\u52d5\u753b\u3067\u8d85\u5e95\u8fba\u6b4c\u3044\u624b\u3092\u3055\u305b\u3066\u9802\u3044\u3066\u3044\u308b\u3010\u3084\u3093\u72ac\u3011\u3067\u3059(=\uff9f\u03c9\uff9f)\uff89 \u3088\u304b\u3063\u305f\u3089\u4ef2\u3088\u304f\u3057\u3066\u3084\u3063\u3066\u304f\u3060\u3055\u3044(=\uff9f\u03c9\uff9f)\uff89 https://t.co/pVrZv15kob",
#             "url": "https://t.co/QyI37r5QQ1",
#             "entities": {
#                 "url": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/QyI37r5QQ1",
#                             "expanded_url": "http://com.nicovideo.jp/community/co1382048",
#                             "display_url": "com.nicovideo.jp/community/co13\u2026",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 },
#                 "description": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/pVrZv15kob",
#                             "expanded_url": "http://www.nicovideo.jp/mylist/25644678",
#                             "display_url": "nicovideo.jp/mylist/25644678",
#                             "indices": [
#                                 68,
#                                 91
#                             ]
#                         }
#                     ]
#                 }
#             },
#             "protected": false,
#             "followers_count": 357,
#             "friends_count": 464,
#             "listed_count": 6,
#             "created_at": "Mon Oct 03 20:29:26 +0000 2011",
#             "favourites_count": 563,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 20889,
#             "lang": "ja",
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "C0DEED",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/554329357221523457/jURXMVce_normal.jpeg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/554329357221523457/jURXMVce_normal.jpeg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/384511849/1504667460",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": true,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none"
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "retweeted_status": {
#             "created_at": "Thu Sep 07 23:00:42 +0000 2017",
#             "id": 905928843566952449,
#             "id_str": "905928843566952449",
#             "text": "\u76f4\u611f\u3067\u3044\u3044\u306a\u3041\u3063\u3066\u601d\u3063\u305f\u4eba\u306fRT\ud83d\ude0f\n\n#toyota #supra #jdm https://t.co/ZnNjqbLITT",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "toyota",
#                         "indices": [
#                             19,
#                             26
#                         ]
#                     },
#                     {
#                         "text": "supra",
#                         "indices": [
#                             27,
#                             33
#                         ]
#                     },
#                     {
#                         "text": "jdm",
#                         "indices": [
#                             34,
#                             38
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [],
#                 "urls": [],
#                 "media": [
#                     {
#                         "id": 905928841771831300,
#                         "id_str": "905928841771831300",
#                         "indices": [
#                             39,
#                             62
#                         ],
#                         "media_url": "http://pbs.twimg.com/media/DJKBe1WXUAQoYV3.jpg",
#                         "media_url_https": "https://pbs.twimg.com/media/DJKBe1WXUAQoYV3.jpg",
#                         "url": "https://t.co/ZnNjqbLITT",
#                         "display_url": "pic.twitter.com/ZnNjqbLITT",
#                         "expanded_url": "https://twitter.com/gooauto/status/905928843566952449/photo/1",
#                         "type": "photo",
#                         "sizes": {
#                             "large": {
#                                 "w": 640,
#                                 "h": 467,
#                                 "resize": "fit"
#                             },
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "small": {
#                                 "w": 640,
#                                 "h": 467,
#                                 "resize": "fit"
#                             },
#                             "medium": {
#                                 "w": 640,
#                                 "h": 467,
#                                 "resize": "fit"
#                             }
#                         }
#                     }
#                 ]
#             },
#             "extended_entities": {
#                 "media": [
#                     {
#                         "id": 905928841771831300,
#                         "id_str": "905928841771831300",
#                         "indices": [
#                             39,
#                             62
#                         ],
#                         "media_url": "http://pbs.twimg.com/media/DJKBe1WXUAQoYV3.jpg",
#                         "media_url_https": "https://pbs.twimg.com/media/DJKBe1WXUAQoYV3.jpg",
#                         "url": "https://t.co/ZnNjqbLITT",
#                         "display_url": "pic.twitter.com/ZnNjqbLITT",
#                         "expanded_url": "https://twitter.com/gooauto/status/905928843566952449/photo/1",
#                         "type": "photo",
#                         "sizes": {
#                             "large": {
#                                 "w": 640,
#                                 "h": 467,
#                                 "resize": "fit"
#                             },
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "small": {
#                                 "w": 640,
#                                 "h": 467,
#                                 "resize": "fit"
#                             },
#                             "medium": {
#                                 "w": 640,
#                                 "h": 467,
#                                 "resize": "fit"
#                             }
#                         }
#                     }
#                 ]
#             },
#             "metadata": {
#                 "iso_language_code": "ja",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"http://www.everypost.me\" rel=\"nofollow\">Everypost</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 3075512468,
#                 "id_str": "3075512468",
#                 "name": "\u6c17\u306b\u306a\u308b\u8eca\u30fb\u30d0\u30a4\u30af\u52d5\u753b\u2744\ufe0f",
#                 "screen_name": "gooauto",
#                 "location": "",
#                 "description": "\u2b50\ufe0f\u5b89\u5fc3\u3068\u4fe1\u983c\u306e\u30d5\u30a9\u30ed\u30ef\u30fc5\u4e07\u4eba\u2b50\ufe0f\u8eca\u3084\u30d0\u30a4\u30af\u597d\u304d\u304c\u6c17\u306b\u306a\u308b\u52d5\u753b\u304b\u3089\u30e2\u30bf\u30b9\u30dd\u30cb\u30e5\u30fc\u30b9\u307e\u3067\u3001\u3068\u306b\u304b\u304f\u76ee\u3067\u898b\u3066\u697d\u3057\u3081\u308b\u8eca\u30fb\u30d0\u30a4\u30af\u60c5\u5831\u3092\u914d\u4fe1\u4e2d\u2764\ufe0f\u57fa\u672c\u7684\u306bDM\u306f\u3057\u307e\u305b\u3093",
#                 "url": "https://t.co/JB9VujE9cy",
#                 "entities": {
#                     "url": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/JB9VujE9cy",
#                                 "expanded_url": "https://goo.to",
#                                 "display_url": "goo.to",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ]
#                             }
#                         ]
#                     },
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 51309,
#                 "friends_count": 44689,
#                 "listed_count": 184,
#                 "created_at": "Thu Mar 12 17:57:54 +0000 2015",
#                 "favourites_count": 56326,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": false,
#                 "statuses_count": 28482,
#                 "lang": "ja",
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "C0DEED",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/792320848396816384/oPnr5kAL_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/792320848396816384/oPnr5kAL_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/3075512468/1471739971",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": false,
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none"
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "is_quote_status": false,
#             "retweet_count": 16,
#             "favorite_count": 60,
#             "favorited": false,
#             "retweeted": false,
#             "possibly_sensitive": false,
#             "lang": "ja"
#         },
#         "is_quote_status": false,
#         "retweet_count": 16,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "ja"
#     },
#     {
#         "created_at": "Fri Sep 08 00:20:10 +0000 2017",
#         "id": 905948842708762624,
#         "id_str": "905948842708762624",
#         "text": "Great day on the Trails, and the Toyota that got me there\n#Toyota #4runner #Mountainbike #Rockymountain #Altitude https://t.co/yZ1lJOjy8l",
#         "truncated": false,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "Toyota",
#                     "indices": [
#                         58,
#                         65
#                     ]
#                 },
#                 {
#                     "text": "4runner",
#                     "indices": [
#                         66,
#                         74
#                     ]
#                 },
#                 {
#                     "text": "Mountainbike",
#                     "indices": [
#                         75,
#                         88
#                     ]
#                 },
#                 {
#                     "text": "Rockymountain",
#                     "indices": [
#                         89,
#                         103
#                     ]
#                 },
#                 {
#                     "text": "Altitude",
#                     "indices": [
#                         104,
#                         113
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [],
#             "urls": [],
#             "media": [
#                 {
#                     "id": 905948796978323456,
#                     "id_str": "905948796978323456",
#                     "indices": [
#                         114,
#                         137
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/DJKToYSV4AAEi2b.jpg",
#                     "media_url_https": "https://pbs.twimg.com/media/DJKToYSV4AAEi2b.jpg",
#                     "url": "https://t.co/yZ1lJOjy8l",
#                     "display_url": "pic.twitter.com/yZ1lJOjy8l",
#                     "expanded_url": "https://twitter.com/AdamJWest84/status/905948842708762624/photo/1",
#                     "type": "photo",
#                     "sizes": {
#                         "large": {
#                             "w": 1536,
#                             "h": 2048,
#                             "resize": "fit"
#                         },
#                         "medium": {
#                             "w": 900,
#                             "h": 1200,
#                             "resize": "fit"
#                         },
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "small": {
#                             "w": 510,
#                             "h": 680,
#                             "resize": "fit"
#                         }
#                     }
#                 }
#             ]
#         },
#         "extended_entities": {
#             "media": [
#                 {
#                     "id": 905948796978323456,
#                     "id_str": "905948796978323456",
#                     "indices": [
#                         114,
#                         137
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/DJKToYSV4AAEi2b.jpg",
#                     "media_url_https": "https://pbs.twimg.com/media/DJKToYSV4AAEi2b.jpg",
#                     "url": "https://t.co/yZ1lJOjy8l",
#                     "display_url": "pic.twitter.com/yZ1lJOjy8l",
#                     "expanded_url": "https://twitter.com/AdamJWest84/status/905948842708762624/photo/1",
#                     "type": "photo",
#                     "sizes": {
#                         "large": {
#                             "w": 1536,
#                             "h": 2048,
#                             "resize": "fit"
#                         },
#                         "medium": {
#                             "w": 900,
#                             "h": 1200,
#                             "resize": "fit"
#                         },
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "small": {
#                             "w": 510,
#                             "h": 680,
#                             "resize": "fit"
#                         }
#                     }
#                 }
#             ]
#         },
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 2720440324,
#             "id_str": "2720440324",
#             "name": "Adam West",
#             "screen_name": "AdamJWest84",
#             "location": "",
#             "description": "Just me",
#             "url": null,
#             "entities": {
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 40,
#             "friends_count": 210,
#             "listed_count": 0,
#             "created_at": "Tue Jul 22 04:40:55 +0000 2014",
#             "favourites_count": 0,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 49,
#             "lang": "en",
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "C0DEED",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/702466670799925248/mTxYJwqM_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/702466670799925248/mTxYJwqM_normal.jpg",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": false,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none"
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 0,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "en"
#     },
#     {
#         "created_at": "Fri Sep 08 00:14:26 +0000 2017",
#         "id": 905947399557758976,
#         "id_str": "905947399557758976",
#         "text": "\u301009:00\u6642\u70b9 26.4\u2103\u3011\n26.6~22.3\u2103\n(\u6771\u90e8)\u2605\u6ce8\u610f\u5831:\u96f7\n\uff1d\u611b\u77e5\u770c\u8c4a\u7530\u5e02 #toyota #\u8c4a\u7530 https://t.co/1S8jADM1M7",
#         "truncated": false,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "toyota",
#                     "indices": [
#                         46,
#                         53
#                     ]
#                 },
#                 {
#                     "text": "\u8c4a\u7530",
#                     "indices": [
#                         54,
#                         57
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [],
#             "urls": [],
#             "media": [
#                 {
#                     "id": 905947397137735680,
#                     "id_str": "905947397137735680",
#                     "indices": [
#                         58,
#                         81
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/DJKSW5eVoAAkHde.jpg",
#                     "media_url_https": "https://pbs.twimg.com/media/DJKSW5eVoAAkHde.jpg",
#                     "url": "https://t.co/1S8jADM1M7",
#                     "display_url": "pic.twitter.com/1S8jADM1M7",
#                     "expanded_url": "https://twitter.com/mgn_toyota/status/905947399557758976/photo/1",
#                     "type": "photo",
#                     "sizes": {
#                         "medium": {
#                             "w": 500,
#                             "h": 200,
#                             "resize": "fit"
#                         },
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "large": {
#                             "w": 500,
#                             "h": 200,
#                             "resize": "fit"
#                         },
#                         "small": {
#                             "w": 500,
#                             "h": 200,
#                             "resize": "fit"
#                         }
#                     }
#                 }
#             ]
#         },
#         "extended_entities": {
#             "media": [
#                 {
#                     "id": 905947397137735680,
#                     "id_str": "905947397137735680",
#                     "indices": [
#                         58,
#                         81
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/DJKSW5eVoAAkHde.jpg",
#                     "media_url_https": "https://pbs.twimg.com/media/DJKSW5eVoAAkHde.jpg",
#                     "url": "https://t.co/1S8jADM1M7",
#                     "display_url": "pic.twitter.com/1S8jADM1M7",
#                     "expanded_url": "https://twitter.com/mgn_toyota/status/905947399557758976/photo/1",
#                     "type": "photo",
#                     "sizes": {
#                         "medium": {
#                             "w": 500,
#                             "h": 200,
#                             "resize": "fit"
#                         },
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "large": {
#                             "w": 500,
#                             "h": 200,
#                             "resize": "fit"
#                         },
#                         "small": {
#                             "w": 500,
#                             "h": 200,
#                             "resize": "fit"
#                         }
#                     }
#                 }
#             ]
#         },
#         "metadata": {
#             "iso_language_code": "ja",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"http://twitter.com/mitdok\" rel=\"nofollow\">\u8c4a\u7530\u3046\u3055\u304ebot</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 481649658,
#             "id_str": "481649658",
#             "name": "\u6c17\u8c61\u3046\u3055\u304e:\u8c4a\u7530",
#             "screen_name": "mgn_toyota",
#             "location": "\u611b\u77e5\u770c\u8c4a\u7530\u5e02",
#             "description": "\u8c4a\u7530\u5e02\u306e\u6c17\u6e29\u3084\u8b66\u5831/\u6ce8\u610f\u5831\u306a\u3069\u3092\u30b0\u30e9\u30d5\u4ed8\u304d\u3067\u3064\u3076\u3084\u304f\u30ed\u30dc\u30c3\u30c8\u3067\u3059\u3002\u5168\u56fd\u306b\u3044\u307e\u3059\u3002\u6c17\u8c61\u5e81\u60c5\u5831\u3002\uff08\u7ba1\u7406\u4eba\uff1a @mitdok \uff09",
#             "url": "https://t.co/eQz5dHbzm7",
#             "entities": {
#                 "url": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/eQz5dHbzm7",
#                             "expanded_url": "http://dokasen.com/kisho.php?id=51116",
#                             "display_url": "dokasen.com/kisho.php?id=5\u2026",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 },
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 1410,
#             "friends_count": 3729,
#             "listed_count": 35,
#             "created_at": "Fri Feb 03 01:07:09 +0000 2012",
#             "favourites_count": 0,
#             "utc_offset": 32400,
#             "time_zone": "Tokyo",
#             "geo_enabled": true,
#             "verified": false,
#             "statuses_count": 52034,
#             "lang": "ja",
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "131516",
#             "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/470006818156998656/4N-Jqun9.png",
#             "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/470006818156998656/4N-Jqun9.png",
#             "profile_background_tile": true,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/470006814323388416/mYj1uL4P_normal.png",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/470006814323388416/mYj1uL4P_normal.png",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/481649658/1400893333",
#             "profile_link_color": "009999",
#             "profile_sidebar_border_color": "EEEEEE",
#             "profile_sidebar_fill_color": "EFEFEF",
#             "profile_text_color": "333333",
#             "profile_use_background_image": false,
#             "has_extended_profile": false,
#             "default_profile": false,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none"
#         },
#         "geo": {
#             "type": "Point",
#             "coordinates": [
#                 35.13166667,
#                 137.17666667
#             ]
#         },
#         "coordinates": {
#             "type": "Point",
#             "coordinates": [
#                 137.17666667,
#                 35.13166667
#             ]
#         },
#         "place": {
#             "id": "c2599e59e5a977d8",
#             "url": "https://api.twitter.com/1.1/geo/id/c2599e59e5a977d8.json",
#             "place_type": "city",
#             "name": "Toyota-shi",
#             "full_name": "Toyota-shi, Aichi",
#             "country_code": "JP",
#             "country": "Japan",
#             "contained_within": [],
#             "bounding_box": {
#                 "type": "Polygon",
#                 "coordinates": [
#                     [
#                         [
#                             137.040008,
#                             34.990489
#                         ],
#                         [
#                             137.581705,
#                             34.990489
#                         ],
#                         [
#                             137.581705,
#                             35.291232
#                         ],
#                         [
#                             137.040008,
#                             35.291232
#                         ]
#                     ]
#                 ]
#             },
#             "attributes": {}
#         },
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 0,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "ja"
#     },
#     {
#         "created_at": "Fri Sep 08 00:01:19 +0000 2017",
#         "id": 905944097055277056,
#         "id_str": "905944097055277056",
#         "text": "#Lamborghini Huracan Surprises Turbo Supra on The Street! - https://t.co/FXaBmXzoW5 #Toyota #Racing https://t.co/qoleC3dJgG",
#         "truncated": false,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "Lamborghini",
#                     "indices": [
#                         0,
#                         12
#                     ]
#                 },
#                 {
#                     "text": "Toyota",
#                     "indices": [
#                         84,
#                         91
#                     ]
#                 },
#                 {
#                     "text": "Racing",
#                     "indices": [
#                         92,
#                         99
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [],
#             "urls": [
#                 {
#                     "url": "https://t.co/FXaBmXzoW5",
#                     "expanded_url": "https://topspeed.one/lamborghini-huracan-surprises-turbo-supra-street/",
#                     "display_url": "topspeed.one/lamborghini-hu\u2026",
#                     "indices": [
#                         60,
#                         83
#                     ]
#                 }
#             ],
#             "media": [
#                 {
#                     "id": 905944095104880642,
#                     "id_str": "905944095104880642",
#                     "indices": [
#                         100,
#                         123
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/DJKPWscW0AIsgKm.jpg",
#                     "media_url_https": "https://pbs.twimg.com/media/DJKPWscW0AIsgKm.jpg",
#                     "url": "https://t.co/qoleC3dJgG",
#                     "display_url": "pic.twitter.com/qoleC3dJgG",
#                     "expanded_url": "https://twitter.com/TopSpeedOne/status/905944097055277056/photo/1",
#                     "type": "photo",
#                     "sizes": {
#                         "large": {
#                             "w": 1024,
#                             "h": 576,
#                             "resize": "fit"
#                         },
#                         "medium": {
#                             "w": 1024,
#                             "h": 576,
#                             "resize": "fit"
#                         },
#                         "small": {
#                             "w": 680,
#                             "h": 383,
#                             "resize": "fit"
#                         },
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         }
#                     }
#                 }
#             ]
#         },
#         "extended_entities": {
#             "media": [
#                 {
#                     "id": 905944095104880642,
#                     "id_str": "905944095104880642",
#                     "indices": [
#                         100,
#                         123
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/DJKPWscW0AIsgKm.jpg",
#                     "media_url_https": "https://pbs.twimg.com/media/DJKPWscW0AIsgKm.jpg",
#                     "url": "https://t.co/qoleC3dJgG",
#                     "display_url": "pic.twitter.com/qoleC3dJgG",
#                     "expanded_url": "https://twitter.com/TopSpeedOne/status/905944097055277056/photo/1",
#                     "type": "photo",
#                     "sizes": {
#                         "large": {
#                             "w": 1024,
#                             "h": 576,
#                             "resize": "fit"
#                         },
#                         "medium": {
#                             "w": 1024,
#                             "h": 576,
#                             "resize": "fit"
#                         },
#                         "small": {
#                             "w": 680,
#                             "h": 383,
#                             "resize": "fit"
#                         },
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         }
#                     }
#                 }
#             ]
#         },
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"http://topspeed.one\" rel=\"nofollow\">topspeed</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 4910690987,
#             "id_str": "4910690987",
#             "name": "TopSpeed ONE",
#             "screen_name": "TopSpeedOne",
#             "location": "",
#             "description": "",
#             "url": "https://t.co/GaXcHZTl5k",
#             "entities": {
#                 "url": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/GaXcHZTl5k",
#                             "expanded_url": "http://topspeed.one",
#                             "display_url": "topspeed.one",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 },
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 752,
#             "friends_count": 2748,
#             "listed_count": 16,
#             "created_at": "Sun Feb 14 22:12:56 +0000 2016",
#             "favourites_count": 3,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 745,
#             "lang": "en",
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "000000",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/709198822740627456/9QSqqhas_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/709198822740627456/9QSqqhas_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/4910690987/1461877611",
#             "profile_link_color": "FF0000",
#             "profile_sidebar_border_color": "000000",
#             "profile_sidebar_fill_color": "000000",
#             "profile_text_color": "000000",
#             "profile_use_background_image": false,
#             "has_extended_profile": false,
#             "default_profile": false,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none"
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 1,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "en"
#     },
#     {
#         "created_at": "Thu Sep 07 23:57:07 +0000 2017",
#         "id": 905943041269215232,
#         "id_str": "905943041269215232",
#         "text": "2000 TOYOTA CRESTA  GX100 - https://t.co/3eAIUnxEs1 #GX100, #TOYOTA, #CRESTA",
#         "truncated": false,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "GX100",
#                     "indices": [
#                         52,
#                         58
#                     ]
#                 },
#                 {
#                     "text": "TOYOTA",
#                     "indices": [
#                         60,
#                         67
#                     ]
#                 },
#                 {
#                     "text": "CRESTA",
#                     "indices": [
#                         69,
#                         76
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [],
#             "urls": [
#                 {
#                     "url": "https://t.co/3eAIUnxEs1",
#                     "expanded_url": "http://jdmvip.com/jdmcars/2000_TOYOTA_CRESTA__GX100-2Qqc7ez6XpOVbhv-7183",
#                     "display_url": "jdmvip.com/jdmcars/2000_T\u2026",
#                     "indices": [
#                         28,
#                         51
#                     ]
#                 }
#             ]
#         },
#         "metadata": {
#             "iso_language_code": "in",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"http://jdmvip.com\" rel=\"nofollow\">nssvip</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 396206618,
#             "id_str": "396206618",
#             "name": "jdmvip.com",
#             "screen_name": "jdmvipcom",
#             "location": "Canada",
#             "description": "I'm addicted to jdm cars and love to discuss, learn and more importantly drive them.",
#             "url": "http://t.co/ZgvVAL1d9k",
#             "entities": {
#                 "url": {
#                     "urls": [
#                         {
#                             "url": "http://t.co/ZgvVAL1d9k",
#                             "expanded_url": "http://jdmvip.com",
#                             "display_url": "jdmvip.com",
#                             "indices": [
#                                 0,
#                                 22
#                             ]
#                         }
#                     ]
#                 },
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 1613,
#             "friends_count": 67,
#             "listed_count": 79,
#             "created_at": "Sat Oct 22 22:35:12 +0000 2011",
#             "favourites_count": 0,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 39271,
#             "lang": "en",
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "C0DEED",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/603073779846094849/Os8n24Vp_normal.png",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/603073779846094849/Os8n24Vp_normal.png",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/396206618/1432619832",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": false,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none"
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 0,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "in"
#     },
#     {
#         "created_at": "Thu Sep 07 23:50:32 +0000 2017",
#         "id": 905941387186544640,
#         "id_str": "905941387186544640",
#         "text": "@ToyotaCanada 500,000km and still going strong #Prius #Toyota #2010prius https://t.co/eZpggX7FeK",
#         "truncated": false,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "Prius",
#                     "indices": [
#                         47,
#                         53
#                     ]
#                 },
#                 {
#                     "text": "Toyota",
#                     "indices": [
#                         54,
#                         61
#                     ]
#                 },
#                 {
#                     "text": "2010prius",
#                     "indices": [
#                         62,
#                         72
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [
#                 {
#                     "screen_name": "ToyotaCanada",
#                     "name": "Toyota Canada",
#                     "id": 20687324,
#                     "id_str": "20687324",
#                     "indices": [
#                         0,
#                         13
#                     ]
#                 }
#             ],
#             "urls": [],
#             "media": [
#                 {
# ...
#                         {
#                             "url": "https://t.co/qQQFQ23rD9",
#                             "expanded_url": "http://www.gregmillertoyota.com",
#                             "display_url": "gregmillertoyota.com",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 },
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 255,
#             "friends_count": 140,
#             "listed_count": 12,
#             "created_at": "Thu Jul 22 21:37:08 +0000 2010",
#             "favourites_count": 18,
#             "utc_offset": -25200,
#             "time_zone": "Pacific Time (US & Canada)",
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 4362,
#             "lang": "en",
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "1A1B1F",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme9/bg.gif",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme9/bg.gif",
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/722860615472013313/x7LCbU5k_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/722860615472013313/x7LCbU5k_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/169659243/1480364118",
#             "profile_link_color": "E81515",
#             "profile_sidebar_border_color": "FFFFFF",
#             "profile_sidebar_fill_color": "252429",
#             "profile_text_color": "666666",
#             "profile_use_background_image": true,
#             "has_extended_profile": false,
#             "default_profile": false,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none"
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 0,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "en"
#     },
#     {
#         "created_at": "Thu Sep 07 19:26:03 +0000 2017",
#         "id": 905874826358919168,
#         "id_str": "905874826358919168",
#         "text": "Adventures start with the right vehicle. Start exploring with the all-new #2018 #Toyota Camry! For more click here:\u2026 https://t.co/8TNlXrpRpK",
#         "truncated": true,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "Toyota",
#                     "indices": [
#                         80,
#                         87
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [],
#             "urls": [
#                 {
#                     "url": "https://t.co/8TNlXrpRpK",
#                     "expanded_url": "https://twitter.com/i/web/status/905874826358919168",
#                     "display_url": "twitter.com/i/web/status/9\u2026",
#                     "indices": [
#                         117,
#                         140
#                     ]
#                 }
#             ]
#         },
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"http://app.sendblur.com\" rel=\"nofollow\">Social Media Publisher App </a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 746725712845930496,
#             "id_str": "746725712845930496",
#             "name": "Gilroy Toyota",
#             "screen_name": "Gilroy_Toyota",
#             "location": "Gilroy, CA",
#             "description": "Welcome! A family owned business that began in 1988 and is still going strong with its original owner today! Stop by, visit our website or call: (408) 848-8000",
#             "url": null,
#             "entities": {
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 2,
#             "friends_count": 0,
#             "listed_count": 0,
#             "created_at": "Sat Jun 25 15:24:18 +0000 2016",
#             "favourites_count": 0,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 192,
#             "lang": "en",
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "F5F8FA",
#             "profile_background_image_url": null,
#             "profile_background_image_url_https": null,
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/746725962327302144/JuSj0m1L_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/746725962327302144/JuSj0m1L_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/746725712845930496/1466868547",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": true,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none"
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 0,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "en"
#     },
#     {
#         "created_at": "Thu Sep 07 19:25:47 +0000 2017",
#         "id": 905874758058864640,
#         "id_str": "905874758058864640",
#         "text": "Adventures start with the right vehicle. Start exploring with the all-new #2018 #Toyota Camry! For more click here:\u2026 https://t.co/izfeEquhXo",
#         "truncated": true,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "Toyota",
#                     "indices": [
#                         80,
#                         87
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [],
#             "urls": [
#                 {
#                     "url": "https://t.co/izfeEquhXo",
#                     "expanded_url": "https://twitter.com/i/web/status/905874758058864640",
#                     "display_url": "twitter.com/i/web/status/9\u2026",
#                     "indices": [
#                         117,
#                         140
#                     ]
#                 }
#             ]
#         },
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"http://app.sendblur.com\" rel=\"nofollow\">Social Media Publisher App </a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 203208222,
#             "id_str": "203208222",
#             "name": "Freeman Toyota",
#             "screen_name": "Freeman_Toyota",
#             "location": "204 NE Loop 820, Hurst, TX",
#             "description": "At Freeman Toyota, you\u2019ll find a huge inventory of new Toyota & Scion vehicles. We offer exceptional service & rock-bottom prices to Dallas County! 855-981-2665",
#             "url": "http://t.co/s5BRhOJGEn",
#             "entities": {
#                 "url": {
#                     "urls": [
#                         {
#                             "url": "http://t.co/s5BRhOJGEn",
#                             "expanded_url": "http://freemantoyota.com/",
#                             "display_url": "freemantoyota.com",
#                             "indices": [
#                                 0,
#                                 22
#                             ]
#                         }
#                     ]
#                 },
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 168,
#             "friends_count": 48,
#             "listed_count": 2,
#             "created_at": "Fri Oct 15 19:33:52 +0000 2010",
#             "favourites_count": 0,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 1476,
#             "lang": "en",
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "FFFFFF",
#             "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/164263254/Twitter_background-1.jpg",
#             "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/164263254/Twitter_background-1.jpg",
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/687039368817594368/hEUfKHO3_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/687039368817594368/hEUfKHO3_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/203208222/1444843745",
#             "profile_link_color": "DD2E44",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": false,
#             "default_profile": false,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none"
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 0,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "en"
#     },
#     {
#         "created_at": "Thu Sep 07 19:25:25 +0000 2017",
#         "id": 905874666262331392,
#         "id_str": "905874666262331392",
#         "text": "Start an adventure and explore with the all-new #2018 #Toyota Camry! For more click here: https://t.co/VlHjK980ya &amp;\u2026 https://t.co/DZKSeOP5I5",
#         "truncated": true,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "Toyota",
#                     "indices": [
#                         54,
#                         61
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [],
#             "urls": [
#                 {
#                     "url": "https://t.co/VlHjK980ya",
#                     "expanded_url": "http://bit.ly/2ff9bhg",
#                     "display_url": "bit.ly/2ff9bhg",
#                     "indices": [
#                         90,
#                         113
#                     ]
#                 },
#                 {
#                     "url": "https://t.co/DZKSeOP5I5",
#                     "expanded_url": "https://twitter.com/i/web/status/905874666262331392",
#                     "display_url": "twitter.com/i/web/status/9\u2026",
#                     "indices": [
#                         121,
#                         144
#                     ]
#                 }
#             ]
#         },
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"http://app.sendblur.com\" rel=\"nofollow\">Social Media Publisher App </a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 3092642848,
#             "id_str": "3092642848",
#             "name": "Freedom Toyota Hrbg",
#             "screen_name": "FreedomToyotaHb",
#             "location": "Harrisburg, PA",
#             "description": "Freedom Toyota is a New and Pre-Owned dealership in Harrisburg, PA serving Dauphin County and the surrounding areas. We can be reached at 717-545-4726.",
#             "url": "http://t.co/dtzvOSGyOG",
#             "entities": {
#                 "url": {
#                     "urls": [
#                         {
#                             "url": "http://t.co/dtzvOSGyOG",
#                             "expanded_url": "http://www.freedomtoyotaofharrisburg.com",
#                             "display_url": "freedomtoyotaofharrisburg.com",
#                             "indices": [
#                                 0,
#                                 22
#                             ]
#                         }
#                     ]
#                 },
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 23,
#             "friends_count": 2,
#             "listed_count": 2,
#             "created_at": "Tue Mar 17 00:00:25 +0000 2015",
#             "favourites_count": 0,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 929,
#             "lang": "en",
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "000000",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/577622593093517312/KyCIn8NF_normal.jpeg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/577622593093517312/KyCIn8NF_normal.jpeg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/3092642848/1432056942",
#             "profile_link_color": "DD2E44",
#             "profile_sidebar_border_color": "000000",
#             "profile_sidebar_fill_color": "000000",
#             "profile_text_color": "000000",
#             "profile_use_background_image": false,
#             "has_extended_profile": false,
#             "default_profile": false,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none"
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 0,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "en"
#     }
# ]

# %% [markdown]
# ## Back to slides

# %% [markdown]
# # Example 6. Extracting text, screen names, and hashtags from tweets

# %%
import time


status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# Explore the first 5 items for each...

print(json.dumps(status_texts[0:5], indent=1))
print(json.dumps(screen_names[0:5], indent=1))
print(json.dumps(hashtags[0:5], indent=1))
print(json.dumps(words[0:5], indent=1))
# Out:
# [
#  "RT @gooauto: \u76f4\u611f\u3067\u3044\u3044\u306a\u3041\u3063\u3066\u601d\u3063\u305f\u4eba\u306fRT\ud83d\ude0f\n\n#toyota #supra #jdm https://t.co/ZnNjqbLITT",
#  "Great day on the Trails, and the Toyota that got me there\n#Toyota #4runner #Mountainbike #Rockymountain #Altitude https://t.co/yZ1lJOjy8l",
#  "\u301009:00\u6642\u70b9 26.4\u2103\u3011\n26.6~22.3\u2103\n(\u6771\u90e8)\u2605\u6ce8\u610f\u5831:\u96f7\n\uff1d\u611b\u77e5\u770c\u8c4a\u7530\u5e02 #toyota #\u8c4a\u7530 https://t.co/1S8jADM1M7",
#  "#Lamborghini Huracan Surprises Turbo Supra on The Street! - https://t.co/FXaBmXzoW5 #Toyota #Racing https://t.co/qoleC3dJgG",
#  "2000 TOYOTA CRESTA  GX100 - https://t.co/3eAIUnxEs1 #GX100, #TOYOTA, #CRESTA"
# ]
# [
#  "gooauto",
#  "ToyotaCanada",
#  "EddyVasquezWao",
#  "you_kun_jp",
#  "sunedrum"
# ]
# [
#  "toyota",
#  "supra",
#  "jdm",
#  "Toyota",
#  "4runner"
# ]
# [
#  "RT",
#  "@gooauto:",
#  "\u76f4\u611f\u3067\u3044\u3044\u306a\u3041\u3063\u3066\u601d\u3063\u305f\u4eba\u306fRT\ud83d\ude0f",
#  "#toyota",
#  "#supra"
# ]

# %% [markdown]
# # Example 7. Creating a basic frequency distribution from the words in tweets

# %%
from collections import Counter

for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print(c.most_common()[:10]) # top 10
# Out:
# [('#Toyota', 117), ('the', 85), ('with', 72), ('RT', 58), ('#toyota', 56), ('start', 34), ('Start', 34), ('all-new', 34), ('#2018', 34), ('Camry!', 34)]
# [('gooauto', 18), ('ToyotaGB', 7), ('MrTJ_808', 6), ('you_kun_jp', 5), ('responsejp', 3), ('TGR_Arg', 3), ('eBay', 2), ('Breezcar_FR', 2), ('KabirMotor', 2), ('ToyotaCanada', 1)]
# [('Toyota', 126), ('toyota', 56), ('supra', 18), ('スープラ', 14), ('TOYOTA', 13), ('jdm', 12), ('トヨタ', 12), ('トミカ', 7), ('toms', 7), ('GT', 7)]

# %% [markdown]
# # Example 8. Using prettytable to display tuples in a nice tabular format

# %%
from prettytable import PrettyTable

for label, data in (('Word', words), 
                    ('Screen Name', screen_names), 
                    ('Hashtag', hashtags)):
    pt = PrettyTable(field_names=[label, 'Count']) 
    c = Counter(data)
    [ pt.add_row(kv) for kv in c.most_common()[:10] ]
    pt.align[label], pt.align['Count'] = 'l', 'r' # Set column alignment
    print(pt)
# Out:
# +---------+-------+
# | Word    | Count |
# +---------+-------+
# | #Toyota |   117 |
# | the     |    85 |
# | with    |    72 |
# | RT      |    58 |
# | #toyota |    56 |
# | start   |    34 |
# | Start   |    34 |
# | all-new |    34 |
# | #2018   |    34 |
# | Camry!  |    34 |
# +---------+-------+
# +--------------+-------+
# | Screen Name  | Count |
# +--------------+-------+
# | gooauto      |    18 |
# | ToyotaGB     |     7 |
# | MrTJ_808     |     6 |
# | you_kun_jp   |     5 |
# | responsejp   |     3 |
# | TGR_Arg      |     3 |
# | eBay         |     2 |
# | Breezcar_FR  |     2 |
# | KabirMotor   |     2 |
# | ToyotaCanada |     1 |
# +--------------+-------+
# +----------+-------+
# | Hashtag  | Count |
# +----------+-------+
# | Toyota   |   126 |
# | toyota   |    56 |
# | supra    |    18 |
# | スープラ |    14 |
# | TOYOTA   |    13 |
# | jdm      |    12 |
# | トヨタ   |    12 |
# | トミカ   |     7 |
# | toms     |     7 |
# | GT       |     7 |
# +----------+-------+

# %% [markdown]
# ## Back to slides

# %% [markdown]
# # Example 9. Calculating lexical diversity for tweets

# %%
# A function for computing lexical diversity
def lexical_diversity(tokens):
    return 1.0*len(set(tokens))/len(tokens) 

# A function for computing the average number of words per tweet
def average_words(statuses):
    total_words = sum([ len(s.split()) for s in statuses ]) 
    return 1.0*total_words/len(statuses)

print(lexical_diversity(words))
print(lexical_diversity(screen_names))
print(lexical_diversity(hashtags))
print(average_words(status_texts))
# Out:
# 0.44924880908757786
# 0.5357142857142857
# 0.40842787682333875
# 13.645

# %% [markdown]
# ## Back to slides

# %% [markdown]
# # Example 10. Finding the most popular retweets

# %%
retweets = [
            # Store out a tuple of these three values ...
            (status['retweet_count'], 
             status['retweeted_status']['user']['screen_name'],
             status['text']) 
            
            # ... for each status ...
            for status in statuses 
            
            # ... so long as the status meets this condition.
                if 'retweeted_status' in status
           ]

# Slice off the first 5 from the sorted results and display each item in the tuple

pt = PrettyTable(field_names=['Count', 'Screen Name', 'Text'])
[ pt.add_row(row) for row in sorted(retweets, reverse=True)[:5] ]
pt.max_width['Text'] = 50
pt.align= 'l'
print(pt)
# Out:
# +-------+-------------+----------------------------------------------+
# | Count | Screen Name | Text                                         |
# +-------+-------------+----------------------------------------------+
# | 129   | gooauto     | RT @gooauto: 直感でいいなぁって思った人はRT😏 |
# |       |             |                                              |
# |       |             | #toyota #スープラ https://t.co/W2eEPjXwI1    |
# | 129   | gooauto     | RT @gooauto: 直感でいいなぁって思った人はRT😏 |
# |       |             |                                              |
# |       |             | #toyota #スープラ https://t.co/W2eEPjXwI1    |
# | 129   | gooauto     | RT @gooauto: 直感でいいなぁって思った人はRT😏 |
# |       |             |                                              |
# |       |             | #toyota #スープラ https://t.co/W2eEPjXwI1    |
# | 129   | gooauto     | RT @gooauto: 直感でいいなぁって思った人はRT😏 |
# |       |             |                                              |
# |       |             | #toyota #スープラ https://t.co/W2eEPjXwI1    |
# | 129   | gooauto     | RT @gooauto: 直感でいいなぁって思った人はRT😏 |
# |       |             |                                              |
# |       |             | #toyota #スープラ https://t.co/W2eEPjXwI1    |
# +-------+-------------+----------------------------------------------+

# %% [markdown]
# ## Back to slides

# %% [markdown]
# #  Example 11. Plotting frequencies of words

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline  


word_counts = sorted(Counter(words).values(), reverse=True)



plt.loglog(word_counts)
plt.ylabel("Freq")
plt.xlabel("Word Rank")

# %% [markdown]
# # Example 12. Generating a histogram of retweet counts

# %%
# Using underscores while unpacking values in
# a tuple is idiomatic for discarding them

counts = [count for count, _, _ in retweets]

plt.hist(counts)
plt.title("Retweets")
plt.xlabel('Bins (number of times retweeted)')
plt.ylabel('Number of tweets in bin')

print(counts)
# Out:
# [1, 1, 1, 1, 2, 5, 11, 1, 1, 3, 613, 2, 2, 1, 11, 11, 11, 11, 5, 5, 3190, 2, 11, 11, 11, 11, 11, 2, 5, 5, 5, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 1, 2, 2, 2, 19, 3, 1, 1, 18, 1, 17, 1, 5]
